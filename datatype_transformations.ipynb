# %% [markdown]
# # Loading Data into a DataFrame

# %%
import pandas as pd
import numpy as np
from datatype_transformations import DataTransform
from datatype_transformations import DataFrameInfo


# Load data into df
df = pd.read_csv('C:/Users/Lara/.vscode/EDA_project_customer_loans_in_finance/milestone_1/loan_payments.csv')
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Viewing DataFrame

# %%
# An overview of the loan payments data
display(df.head())
print('------------')
display(df.tail())
# Out:
#          id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0  38676116   41461848         8000         8000.0             8000.0
# 1  38656203   41440010        13200        13200.0            13200.0
# 2  38656154   41439961        16000        16000.0            16000.0
# 3  38656128   41439934        15000        15000.0            15000.0
# 4  38656121   41439927        15000        15000.0            15000.0
#
#         term  int_rate  instalment grade sub_grade  ... recoveries  \
# 0  36 months      7.49      248.82     A        A4  ...        0.0
# 1  36 months      6.99      407.52     A        A3  ...        0.0
# 2  36 months      7.49      497.63     A        A4  ...        0.0
# 3  36 months     14.31      514.93     C        C4  ...        0.0
# 4  36 months      6.03      456.54     A        A1  ...        0.0
#
#   collection_recovery_fee  last_payment_date last_payment_amount  \
# 0                     0.0             Jan-22              248.82
# ...

# %% [markdown]
# # Data Information

# %%
# shape of the DataFrame

display(df.shape)
# Out:
# (54231, 43)

# %%
# general information about the loan payments DataFrame

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           54231 non-null  int64
#  1   member_id                    54231 non-null  int64
#  2   loan_amount                  54231 non-null  int64
#  3   funded_amount                51224 non-null  float64
#  4   funded_amount_inv            54231 non-null  float64
#  5   term                         49459 non-null  object
#  6   int_rate                     49062 non-null  float64
#  7   instalment                   54231 non-null  float64
#  8   grade                        54231 non-null  object
#  9   sub_grade                    54231 non-null  object
#  10  employment_length            52113 non-null  object
#  11  home_ownership               54231 non-null  object
#  12  annual_inc                   54231 non-null  float64
# ...

# %%
# Summary statistics for the loan payments DataFrame

display(df.describe())
# Out:
#                  id     member_id   loan_amount  funded_amount  \
# count  5.423100e+04  5.423100e+04  54231.000000   51224.000000
# mean   7.621797e+06  8.655350e+06  13333.076100   13229.509117
# std    9.571362e+06  1.031281e+07   8082.196709    8019.017599
# min    5.552100e+04  7.069400e+04    500.000000     500.000000
# 25%    7.594330e+05  9.587720e+05   7000.000000    7000.000000
# 50%    7.084590e+06  8.709873e+06  12000.000000   12000.000000
# 75%    8.860616e+06  1.052714e+07  18000.000000   18000.000000
# max    3.867612e+07  4.146185e+07  35000.000000   35000.000000
#
#        funded_amount_inv      int_rate    instalment    annual_inc  \
# count       54231.000000  49062.000000  54231.000000  5.423100e+04
# mean        12952.622979     13.507328    400.013953  7.222085e+04
# std          8099.473527      4.392893    238.920012  5.158934e+04
# min             0.000000      5.420000     15.670000  3.300000e+03
# ...

# %%
# The count of NULL values in each column

display(df.isnull().sum())
# Out:
# id                                 0
# member_id                          0
# loan_amount                        0
# funded_amount                   3007
# funded_amount_inv                  0
# term                            4772
# int_rate                        5169
# instalment                         0
# grade                              0
# sub_grade                          0
# employment_length               2118
# home_ownership                     0
# annual_inc                         0
# verification_status                0
# issue_date                         0
# loan_status                        0
# payment_plan                       0
# purpose                            0
# dti                                0
# delinq_2yrs                        0
# earliest_credit_line               0
# inq_last_6mths                     0
# mths_since_last_delinq         31002
# mths_since_last_record         48050
# open_accounts                      0
# ...

# %%
# The number of unique values in each column
display(df.nunique(axis= 0))
# Out:
# id                             54231
# member_id                      54231
# loan_amount                     1083
# funded_amount                   1122
# funded_amount_inv               5261
# term                               2
# int_rate                         457
# instalment                     19940
# grade                              7
# sub_grade                         35
# employment_length                 11
# home_ownership                     5
# annual_inc                      6132
# verification_status                3
# issue_date                        61
# loan_status                        9
# payment_plan                       2
# purpose                           14
# dti                             3611
# delinq_2yrs                       16
# earliest_credit_line             587
# inq_last_6mths                    24
# mths_since_last_delinq           100
# mths_since_last_record           120
# open_accounts                     48
# ...

# %%
#The frequency of each unique value in each column

for column in df.columns:
    value_counts = df[column].value_counts()
    print(f"Column: {column}")
    print(value_counts)
    print("-------------------")
# Out:
# Column: id
# id
# 38676116    1
# 977772      1
# 978511      1
# 978610      1
# 978315      1
#            ..
# 8118025     1
# 8118008     1
# 8117993     1
# 8117883     1
# 72323       1
# Name: count, Length: 54231, dtype: int64
# -------------------
# Column: member_id
# member_id
# 41461848    1
# 1200591     1
# 1201556     1
# 1201469     1
# 1201371     1
#            ..
# 9859996     1
# 9859978     1
# 9859963     1
# 9859862     1
# 70694       1
# Name: count, Length: 54231, dtype: int64
# -------------------
# Column: loan_amount
# loan_amount
# 10000    3951
# 12000    3062
# 15000    2844
# 20000    2625
# 5000     2013
#          ...
# 15375       1
# 28675       1
# 13525       1
# 27725       1
# 24750       1
# Name: count, Length: 1083, dtype: int64
# -------------------
# Column: funded_amount
# funded_amount
# 10000.0    3703
# 12000.0    2863
# 15000.0    2637
# 20000.0    2418
# 5000.0     1913
#            ...
# 19225.0       1
# 20900.0       1
# ...

# %% [markdown]
# - Complete the display of information via the DataFrameInfo class

# %%
df_info = DataFrameInfo(df)

# Call the methods of DataFrameInfo on df_info

df_info.display_head_tail()
df_info.display_shape()
df_info.display_info()
df_info.display_describe()
df_info.display_missing_values()
df_info.display_unique_values()

# %% [markdown]
# # Data Transformations

# %% [markdown]
# ## Transform columns to datetime
#
# Based on the datatypes of the column shown in the df.info() function, it is necessary to transform the format of some of the columns so that they are correctly labelled.
#
# The following columns will be transformed from strings to datetime in the str_to_datetime() function:
#
# - issue_date
# - earliest_credit_line
# - last_payment_date
# - next_payment_date
# - last_credit_pull_date

# %%
# Transform columns to datetime

df['issue_date'] = pd.to_datetime(df['issue_date'], format ='%b-%y')
df['earliest_credit_line'] = pd.to_datetime(df['earliest_credit_line'], format ='%b-%y')
df['last_payment_date'] = pd.to_datetime(df['last_payment_date'], format ='%b-%y')
df['next_payment_date'] = pd.to_datetime(df['next_payment_date'], format ='%b-%y')
df['last_credit_pull_date'] = pd.to_datetime(df['last_credit_pull_date'], format ='%b-%y')

# %% [markdown]
# ## Tranform columns to category
#
# Based on the low number of unique values shown in df.nunique(), the following columns will be transformed from strings and integers to categories in the str_to_category() function:
#
# - grade
# - term
# - sub_grade
# - home_ownership
# - verification_status
# - loan_status
# - purpose
# - collections_12_mths_ex_med
# - employment_length
#
# The columns policy_code and application_type only have one unique value therefore do not contribute meaningful information to the analysis and will be dropped. It will be noted that the application types are all individual and that the policy code for every ID is 1.

# %%
# Transform columns to category

columns_to_category = ['verification_status', 'loan_status', 'grade', 'term', 'sub_grade', 'purpose', 'home_ownership', 'collections_12_mths_ex_med', 'employment_length']

df[columns_to_category] = df[columns_to_category].astype('category')

# %% [markdown]
# ## Transform columns to boolean
#
# Based on the prescence of only two unique values in a column, not including NULL values, as shown in df.nunique(), the following columns will be transformed from strings and integers into booleans:
#
# -payment_plan

# %%
# Transform columns to boolean

df['payment_plan'] = df['payment_plan'].astype(bool)

# %% [markdown]
# ## Transform columns to numeric
#
# The following columns will be transformed from strings to integers in the str_to_numeric() function:
#
# - loan_amount
# - funded_amount
# - int_rate
# - annual_inc

# %%
# Transform columns to numeric

columns_to_numeric= ['loan_amount', 'funded_amount', 'int_rate', 'annual_inc']

def convert_numeric_columns(self, columns_to_numeric):
        for col in columns_to_numeric:
            self.df[col] = pd.to_numeric(self.df[col], errors='coerce')
        return self.df

# %%
# View changes to datatype for all columns
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           54231 non-null  int64
#  1   member_id                    54231 non-null  int64
#  2   loan_amount                  54231 non-null  int64
#  3   funded_amount                51224 non-null  float64
#  4   funded_amount_inv            54231 non-null  float64
#  5   term                         49459 non-null  category
#  6   int_rate                     49062 non-null  float64
#  7   instalment                   54231 non-null  float64
#  8   grade                        54231 non-null  category
#  9   sub_grade                    54231 non-null  category
#  10  employment_length            52113 non-null  category
#  11  home_ownership               54231 non-null  category
# ...

# %% [markdown]
# - Complete the transformation of the data via the DataTransform class

# %%
dt = DataTransform(df)

#  call the method

transformed_df = dt.transform_all_columns()
display(transformed_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
